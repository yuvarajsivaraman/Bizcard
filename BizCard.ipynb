# %%
! pip install easyocr -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 33.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 29.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 19.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 62.3 MB/s eta 0:00:00

# %%
import easyocr
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt

# %%
import sqlite3
con = sqlite3.connect("/content/drive/MyDrive/Bizcard.db")
cur = con.cursor()

# %% [markdown]
# card no:1

# %%
create_table_query = """
    CREATE TABLE IF NOT EXISTS selva_dig (
        card_holder_name TEXT,
        designation TEXT,
        mobile_number TEXT,
        gmail TEXT,
        address TEXT,
        company_name TEXT
    )
"""
cur.execute(create_table_query)
con.commit()

Reader = easyocr.Reader(['en'])
image_path = '/content/drive/MyDrive/1.png'
results = Reader.readtext(image_path)
texts = [text for (_, text, _) in results]
# print(texts)
data_to_insert = {
    'card_holder_name': texts[0],
    'designation': texts[1],
    'mobile_number': f"{texts[2]}, {texts[3]}",
    'gmail': f"{texts[4]}, {texts[5]}",
    'address': f"{texts[6]} {texts[8]}",
    'company_name': f"{texts[7]}, {texts[9]}"
}
insert_query = """
    INSERT INTO selva_dig
    (card_holder_name, designation, mobile_number, gmail, address, company_name)
    VALUES
    (?, ?, ?, ?, ?, ?)
"""
img = Image.open(image_path)
plt.imshow(img)
plt.axis('off')
plt.show()

# cur.execute(insert_query, (
#     data_to_insert['card_holder_name'],
#     data_to_insert['designation'],
#     data_to_insert['mobile_number'],
#     data_to_insert['gmail'],
#     data_to_insert['address'],
#     data_to_insert['company_name']
# ))

# con.commit()
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
selva_Dt = pd.read_sql_query('''SELECT * FROM selva_dig''', con)
selva_Dt
# Out:
#   card_holder_name   designation                 mobile_number  \
# 0            Selva  DATA MANAGER  +123-456-7890, +123-456-7891
#
#                           gmail                                 address  \
# 0  WWW XYZI.com, hello@XYZ1.com  123 ABC St , Chennai; TamilNadu 600113
#
#     company_name
# 0  Selvadigitals

# %% [markdown]
# card no:2

# %%
create_table_query = """
    CREATE TABLE IF NOT EXISTS global_ins (
        card_holder_name TEXT,
        designation TEXT,
        mobile_number TEXT,
        gmail TEXT,
        address TEXT,
        company_name TEXT
    )
"""
cur.execute(create_table_query)
con.commit()

Reader = easyocr.Reader(['en'])
image_path = '/content/drive/MyDrive/2.png'
results = Reader.readtext(image_path)
texts = [text for (_, text, _) in results]

data_to_insert = {
    'card_holder_name': texts[0],
    'designation': texts[1],
    'mobile_number': texts[2],
    'gmail': f"{texts[3]}, {texts[4]},{texts[5]}",
    'address': f"{texts[6]}, {texts[7]},{texts[9]}",
    'company_name':f"{texts[8]}, {texts[10]}"
}

img = Image.open(image_path)
plt.imshow(img)
plt.axis('off')
plt.show()

insert_query = """
    INSERT INTO global_ins
    (card_holder_name, designation, mobile_number, gmail, address, company_name)
    VALUES
    (?, ?, ?, ?, ?, ?)
"""

# cur.execute(insert_query, (
#     data_to_insert['card_holder_name'],
#     data_to_insert['designation'],
#     data_to_insert['mobile_number'],
#     data_to_insert['gmail'],
#     data_to_insert['address'],
#     data_to_insert['company_name']
# ))

con.commit()
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
 pd.read_sql_query('''SELECT * FROM global_ins''', con)
# Out:
#   card_holder_name    designation mobile_number  \
# 0       Amit kumar  CEO & FOUNDER  123-456-7569
#
#                               gmail                              address  \
# 0  hello@global.com, WWW,global.com  123 global, Erode,,TamilNadu 600115
#
#         company_name
# 0  GLOBAL, INSURANCE

# %%
create_table_query = """
    CREATE TABLE IF NOT EXISTS Borcelle_airlines (
        card_holder_name TEXT,
        designation TEXT,
        mobile_number TEXT,
        gmail TEXT,
        address TEXT,
        company_name TEXT
    )
"""
cur.execute(create_table_query)
con.commit()

Reader = easyocr.Reader(['en'])
image_path = '/content/drive/MyDrive/3.png'
results = Reader.readtext(image_path)
texts = [text for (_, text, _) in results]

data_to_insert = {
    'card_holder_name': texts[0],
    'designation': texts[1],
    'mobile_number': texts[4],
    'gmail': f"{texts[5]}, {texts[6]}",
    'address': f"{texts[2]}, {texts[3]}",
    'company_name':f"{texts[7]}, {texts[8]}"
}

img = Image.open(image_path)
plt.imshow(img)
plt.axis('off')
plt.show()

insert_query = """
    INSERT INTO Borcelle_airlines
    (card_holder_name, designation, mobile_number, gmail, address, company_name)
    VALUES
    (?, ?, ?, ?, ?, ?)
"""

# cur.execute(insert_query, (
#     data_to_insert['card_holder_name'],
#     data_to_insert['designation'],
#     data_to_insert['mobile_number'],
#     data_to_insert['gmail'],
#     data_to_insert['address'],
#     data_to_insert['company_name']
# ))

# con.commit()
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
 pd.read_sql_query('''SELECT * FROM Borcelle_airlines''', con)
# Out:
#   card_holder_name      designation  mobile_number  \
# 0         KARTHICK  General Manager  +123-456-7890
#
#                                   gmail  \
# 0  hello@Borcelle.com, www Borcelle.com
#
#                                   address        company_name
# 0  123 ABC St , Salem,, TamilNadu 6004513  BORCELLE, AIRLINES

# %% [markdown]
# card no :4

# %%
create_table_query = """
    CREATE TABLE IF NOT EXISTS Family_restaurant (
        card_holder_name TEXT,
        designation TEXT,
        mobile_number TEXT,
        gmail TEXT,
        address TEXT,
        company_name TEXT
    )
"""
cur.execute(create_table_query)
con.commit()

Reader = easyocr.Reader(['en'])
image_path = '/content/drive/MyDrive/4.png'
results = Reader.readtext(image_path)
texts = [text for (_, text, _) in results]
# pprint(texts)
data_to_insert = {
    'card_holder_name': texts[0],
    'designation': texts[1],
    'mobile_number': texts[4],
    'gmail': f"{texts[5]}, {texts[7]}",
    'address': f"{texts[2]}, {texts[3]}",
    'company_name':f"{texts[6]}, {texts[8]}"
}

img = Image.open(image_path)
plt.imshow(img)
plt.axis('off')
plt.show()

insert_query = """
    INSERT INTO Family_restaurant
    (card_holder_name, designation, mobile_number, gmail, address, company_name)
    VALUES
    (?, ?, ?, ?, ?, ?)
"""

# cur.execute(insert_query, (
#     data_to_insert['card_holder_name'],
#     data_to_insert['designation'],
#     data_to_insert['mobile_number'],
#     data_to_insert['gmail'],
#     data_to_insert['address'],
#     data_to_insert['company_name']
# ))

con.commit()
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
pd.read_sql_query('''SELECT * FROM Family_restaurant''', con)
# Out:
#   card_holder_name          designation mobile_number  \
# 0          REVANTH  Marketing Executive  +91-456-1234
#
#                                     gmail  \
# 0  hello@CHRISTMAS.com, wWW.CHRISTMAS.com
#
#                                      address        company_name
# 0  123 ABC St,, HYDRABAD, TamilNadu;, 600001  Family, Restaurant

# %% [markdown]
# card no :5

# %%
create_table_query = """
    CREATE TABLE IF NOT EXISTS Sun_electricals (
        card_holder_name TEXT,
        designation TEXT,
        mobile_number TEXT,
        gmail TEXT,
        address TEXT,
        company_name TEXT
    )
"""
cur.execute(create_table_query)
con.commit()

Reader = easyocr.Reader(['en'])
image_path = '/content/drive/MyDrive/5.png'
results = Reader.readtext(image_path)
texts = [text for (_, text, _) in results]

data_to_insert = {
    'card_holder_name': texts[0],
    'designation': texts[1],
    'mobile_number': texts[4],
    'gmail': f"{texts[5]}, {texts[6]}",
    'address': f"{texts[2]}, {texts[3]}",
    'company_name':texts[7]
}

img = Image.open(image_path)
plt.imshow(img)
plt.axis('off')
plt.show()

insert_query = """
    INSERT INTO Sun_electricals
    (card_holder_name, designation, mobile_number, gmail, address, company_name)
    VALUES
    (?, ?, ?, ?, ?, ?)
"""

# cur.execute(insert_query, (
#     data_to_insert['card_holder_name'],
#     data_to_insert['designation'],
#     data_to_insert['mobile_number'],
#     data_to_insert['gmail'],
#     data_to_insert['address'],
#     data_to_insert['company_name']
# ))

con.commit()
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
pd.read_sql_query('''SELECT * FROM Sun_electricals''', con)
# Out:
#   card_holder_name        designation  mobile_number  \
# 0         SANTHOSH  Technical Manager  +123-456-1234
#
#                        gmail                                   address  \
# 0  hello@Sun.com, www.Suncom  123 ABC St , Tirupur; TamilNadu,, 641603
#
#       company_name
# 0  Sun Electricals
